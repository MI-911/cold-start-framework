# %%
import json
import matplotlib.pyplot as plt

data = json.load(open('gain_popularity_ml.json', 'r'))


plt.plot(data['x'], data['y'])
plt.xlabel('Popularity')
plt.ylabel('Gain')
plt.xlim(1, 500)
plt.yscale('log')
plt.show()
