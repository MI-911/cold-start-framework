# %%
import json
import matplotlib.pyplot as plt

data = json.load(open('entity_scores.json', 'r'))

x = [pair[0] for pair in data]
y = [pair[1] * 100 for pair in data]

plt.scatter(x, y)
plt.xlabel('Entity popularity rank')
plt.ylabel('Gain (NDCG)')
plt.show()
